# %%
# ======== Loading Pkgs and functions =========
@time include(joinpath(@__DIR__, "functions/preload.jl"))
include(joinpath(@__DIR__, "functions/helper_fun.jl"))
show_avail_functions()
# =============================================




# ======= Loading model ======
@time include(joinpath(@__DIR__, "functions/models.jl"))
# =================================




# ======= Single gene case =======
run_path = joinpath(@__DIR__, "functions/single_gene_case.jl")
include(run_path);
run_and_check_new_vars(run_path)
# ============================================================
# Out:
#   Activating project at `~/Desktop/M1_pro_Projects/Notch_EMT/Notch_Epi/Notch_force_ligand_dynamics/Notch_EMT_tutorial`
# [ Info: Current working directory: /Users/chentianchi/Desktop/M1_pro_Projects/Notch_EMT/Notch_Epi/Notch_force_ligand_dynamics/Notch_EMT_tutorial
#  17.634871 seconds (31.66 M allocations: 2.101 GiB, 4.56% gc time, 31.26% compilation time: 38% of which was recompilation)
# [:Base, :Core, :Main, :ans, :current_folder_path]species(model) = SymbolicUtils.Term{Real, Base.ImmutableDict{DataType, Any}}[R(t), NR(t), M(t), MR(t), KDM5A(t), H4(t), H0(t), PRC2(t), H27(t), KDM6A(t), KMT(t)]
# parameters(model) = SymbolicUtils.Sym{Real, Base.ImmutableDict{DataType, Any}}[k0, k1, k2, d, m, p, k, pp, kk, δ, α1, w, A, ϕ]
# speciesmap(model) = Dict{SymbolicUtils.Term{Real, Base.ImmutableDict{DataType, Any}}, Int64}(H4(t) => 6, H0(t) => 7, H27(t) => 9, KDM6A(t) => 10, R(t) => 1, NR(t) => 2, KDM5A(t) => 5, KMT(t) => 11, MR(t) => 4, M(t) => 3, PRC2(t) => 8)
# paramsmap(model) = Dict{SymbolicUtils.Sym{Real, Base.ImmutableDict{DataType, Any}}, Int64}(p => 6, k2 => 3, m => 5, kk => 9, k1 => 2, A => 13, k => 7, pp => 8, k0 => 1, d => 4, α1 => 11, ϕ => 14, δ => 10, w => 12)
# species(model) = SymbolicUtils.Term{Real, Base.ImmutableDict{DataType, Any}}[R(t), NR(t), M(t), MR(t), KDM5A(t), H4(t), H0(t), PRC2(t), H27(t), KDM6A(t), KMT(t)]
# parameters(model) = SymbolicUtils.Sym{Real, Base.ImmutableDict{DataType, Any}}[k0, k1, k2, d, m, p, k, pp, kk, δ, α1, w, A, ϕ]
# speciesmap(model) = Dict{SymbolicUtils.Term{Real, Base.ImmutableDict{DataType, Any}}, Int64}(H4(t) => 6, H0(t) => 7, H27(t) => 9, KDM6A(t) => 10, R(t) => 1, NR(t) => 2, KDM5A(t) => 5, KMT(t) => 11, MR(t) => 4, M(t) => 3, PRC2(t) => 8)
# paramsmap(model) = Dict{SymbolicUtils.Sym{Real, Base.ImmutableDict{DataType, Any}}, Int64}(p => 6, k2 => 3, m => 5, kk => 9, k1 => 2, A => 13, k => 7, pp => 8, k0 => 1, d => 4, α1 => 11, ϕ => 14, δ => 10, w => 12)
# latexify(ODE_equations) = L"\begin{align}
# \frac{\mathrm{d} R\left( t \right)}{\mathrm{d}t} =& k2 \mathrm{MR}\left( t \right) - A \left( 1 + \mathrm{sign}\left( \cos\left( \phi + t w \right) \right) \right) R\left( t \right) - k1 M\left( t \right) R\left( t \right) + \mathrm{NR}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{NR}\left( t \right)}{\mathrm{d}t} =&  - \mathrm{NR}\left( t \right) + A \left( 1 + \mathrm{sign}\left( \cos\left( \phi + t w \right) \right) \right) R\left( t \right) \\
# \frac{\mathrm{d} M\left( t \right)}{\mathrm{d}t} =& k2 \mathrm{MR}\left( t \right) - k1 M\left( t \right) R\left( t \right) \\
# \frac{\mathrm{d} \mathrm{MR}\left( t \right)}{\mathrm{d}t} =&  - k2 \mathrm{MR}\left( t \right) + k1 M\left( t \right) R\left( t \right) \\
# \frac{\mathrm{d} \mathrm{KDM5A}\left( t \right)}{\mathrm{d}t} =& {\alpha}1 + k \mathrm{H27}\left( t \right) + k0 \mathrm{MR}\left( t \right) - \delta \mathrm{KDM5A}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{H4}\left( t \right)}{\mathrm{d}t} =& \mathrm{H0}\left( t \right) \mathrm{KMT}\left( t \right) - d \mathrm{H4}\left( t \right) \mathrm{KDM5A}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{H0}\left( t \right)}{\mathrm{d}t} =& \mathrm{H27}\left( t \right) \mathrm{KDM6A}\left( t \right) - \mathrm{H0}\left( t \right) \mathrm{KMT}\left( t \right) + d \mathrm{H4}\left( t \right) \mathrm{KDM5A}\left( t \right) - m \mathrm{H0}\left( t \right) \mathrm{PRC2}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{PRC2}\left( t \right)}{\mathrm{d}t} =& {\alpha}1 + p \mathrm{H27}\left( t \right) - \delta \mathrm{PRC2}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{H27}\left( t \right)}{\mathrm{d}t} =&  - \mathrm{H27}\left( t \right) \mathrm{KDM6A}\left( t \right) + m \mathrm{H0}\left( t \right) \mathrm{PRC2}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{KDM6A}\left( t \right)}{\mathrm{d}t} =& {\alpha}1 + kk \mathrm{H4}\left( t \right) - \delta \mathrm{KDM6A}\left( t \right) \\
# \frac{\mathrm{d} \mathrm{KMT}\left( t \right)}{\mathrm{d}t} =& {\alpha}1 + pp \mathrm{H4}\left( t \right) - \delta \mathrm{KMT}\left( t \right)
# \end{align}
# "
# The CRN for pulsatile model is: \begin{align*}
# \require{mhchem}
# \ce{ R &<=>[$A \left( 1 + \mathrm{sign}\left( \cos\left( \phi + t w \right) \right) \right)$][$1.0$] NR}\\
# \ce{ M + R &<=>[$k1$][$k2$] MR}\\
# \ce{ MR &->[$k0$] MR + KDM5A}\\
# \ce{ H4 + KDM5A &->[$d$] H0 + KDM5A}\\
# \ce{ H0 + PRC2 &->[$m$] H27 + PRC2}\\
# \ce{ H27 + KDM6A &->[$1.0$] H0 + KDM6A}\\
# \ce{ H0 + KMT &->[$1.0$] H4 + KMT}\\
# \ce{ H27 &->[$p$] H27 + PRC2}\\
# \ce{ H4 &->[$kk$] H4 + KDM6A}\\
# \ce{ H4 &->[$pp$] H4 + KMT}\\
# \ce{ H27 &->[$k$] H27 + KDM5A}\\
# \ce{ PRC2 &->[$\delta$] \varnothing}\\
# \ce{ KDM5A &->[$\delta$] \varnothing}\\
# \ce{ KDM6A &->[$\delta$] \varnothing}\\
# \ce{ KMT &->[$\delta$] \varnothing}\\
# \ce{ \varnothing &->[${\alpha}1$] KDM6A}\\
# \ce{ \varnothing &->[${\alpha}1$] KMT}\\
# \ce{ \varnothing &->[${\alpha}1$] PRC2}\\
# \ce{ \varnothing &->[${\alpha}1$] KDM5A}
# \end{align*}
#
#  36.344704 seconds (55.59 M allocations: 3.152 GiB, 4.35% gc time, 99.65% compilation time)
# ┌ Info: Processing signal
# │   db_idx = 592
# │   freq = 0.0
# │   phase = 0
# │   amplitude = 220
# │   T_init = 1.0e-10
# │   ΔT = 100
# └   tspan = (0.0, 350.0)
# ┌ Info: Model selected: \begin{align*}
# │ \require{mhchem}
# │ \ce{ R &<=>[$A \left( 1 + \mathrm{sign}\left( \cos\left( \phi + t w \right) \right) \right)$][$1.0$] NR}\\
# │ \ce{ M + R &<=>[$k1$][$k2$] MR}\\
# │ \ce{ MR &->[$k0$] MR + KDM5A}\\
# │ \ce{ H4 + KDM5A &->[$d$] H0 + KDM5A}\\
# │ \ce{ H0 + PRC2 &->[$m$] H27 + PRC2}\\
# │ \ce{ H27 + KDM6A &->[$1.0$] H0 + KDM6A}\\
# │ \ce{ H0 + KMT &->[$1.0$] H4 + KMT}\\
# │ \ce{ H27 &->[$p$] H27 + PRC2}\\
# │ \ce{ H4 &->[$kk$] H4 + KDM6A}\\
# │ \ce{ H4 &->[$pp$] H4 + KMT}\\
# │ \ce{ H27 &->[$k$] H27 + KDM5A}\\
# │ \ce{ PRC2 &->[$\delta$] \varnothing}\\
# │ \ce{ KDM5A &->[$\delta$] \varnothing}\\
# │ \ce{ KDM6A &->[$\delta$] \varnothing}\\
# │ \ce{ KMT &->[$\delta$] \varnothing}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KDM6A}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KMT}\\
# │ \ce{ \varnothing &->[${\alpha}1$] PRC2}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KDM5A}
# └ \end{align*}
# ┌ Info: Switching time:
# └   t_switching = 12.270063147371097
# ┌ Info: Processing signal
# │   db_idx = 592
# │   freq = 0.0
# │   phase = 0
# │   amplitude = 220
# │   T_init = 1.0e-10
# │   ΔT = 100
# └   tspan = (0.0, 350.0)
# ┌ Info: Model selected: \begin{align*}
# │ \require{mhchem}
# │ \ce{ R &<=>[$A \left( 1 + \mathrm{sign}\left( \cos\left( \phi + t w \right) \right) \right)$][$1.0$] NR}\\
# │ \ce{ M + R &<=>[$k1$][$k2$] MR}\\
# │ \ce{ MR &->[$k0$] MR + KDM5A}\\
# │ \ce{ H4 + KDM5A &->[$d$] H0 + KDM5A}\\
# │ \ce{ H0 + PRC2 &->[$m$] H27 + PRC2}\\
# │ \ce{ H27 + KDM6A &->[$1.0$] H0 + KDM6A}\\
# │ \ce{ H0 + KMT &->[$1.0$] H4 + KMT}\\
# │ \ce{ H27 &->[$p$] H27 + PRC2}\\
# │ \ce{ H4 &->[$kk$] H4 + KDM6A}\\
# │ \ce{ H4 &->[$pp$] H4 + KMT}\\
# │ \ce{ H27 &->[$k$] H27 + KDM5A}\\
# │ \ce{ PRC2 &->[$\delta$] \varnothing}\\
# │ \ce{ KDM5A &->[$\delta$] \varnothing}\\
# │ \ce{ KDM6A &->[$\delta$] \varnothing}\\
# │ \ce{ KMT &->[$\delta$] \varnothing}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KDM6A}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KMT}\\
# │ \ce{ \varnothing &->[${\alpha}1$] PRC2}\\
# │ \ce{ \varnothing &->[${\alpha}1$] KDM5A}
# └ \end{align*}
# ┌ Info: Switching time:
# └   t_switching = 12.270063147371097
# Newly created variables: Symbol[]

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
